# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.3.9
# Out:
# Collecting sqlalchemy==1.3.9
#   Downloading SQLAlchemy-1.3.9.tar.gz (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 13.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.9-cp311-cp311-macosx_10_9_x86_64.whl size=1153814 sha256=92dd967afaac9c7ed107a3bf338279e9f1612c4708a2c66f43ce25801fa5e6c6
#   Stored in directory: /Users/benmatthew/Library/Caches/pip/wheels/3a/7c/1e/12404784a68083eb969f877a1808a1847bab897684b56ddc55
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
# Successfully installed sqlalchemy-1.3.9

# %%
# !pip install sql
# Out:
# Collecting sql
#   Downloading sql-2022.4.0.tar.gz (4.2 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sql
#   Building wheel for sql (setup.py) ... done
#   Created wheel for sql: filename=sql-2022.4.0-py3-none-any.whl size=4307 sha256=9e9efa682dc9e774cd9f61dddabc621549f52e5fd924ee485f928ec67e2fc60a
#   Stored in directory: /Users/benmatthew/Library/Caches/pip/wheels/a6/f1/62/be6faba20c8384c5766c0332c93841b610ab2602d6ae312bbf
# Successfully built sql
# Installing collected packages: sql
# Successfully installed sql-2022.4.0

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql
# Out:
# The sql module is not an IPython extension.

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas==1.1.5
# Out:
# ^C
# ERROR: Operation cancelled by user

# %%
# %sql sqlite:///my_data1.db
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %%
df = pd.read_csv('Spacex.csv')
# Out:
#            Date Time (UTC) Booster_Version   Launch_Site  \
# 0    2010-06-04   18:45:00  F9 v1.0  B0003   CCAFS LC-40
# 1    2010-12-08   15:43:00  F9 v1.0  B0004   CCAFS LC-40
# 2    2012-05-22    7:44:00  F9 v1.0  B0005   CCAFS LC-40
# 3    2012-10-08    0:35:00  F9 v1.0  B0006   CCAFS LC-40
# 4    2013-03-01   15:10:00  F9 v1.0  B0007   CCAFS LC-40
# ..          ...        ...             ...           ...
# 96   2020-11-05   23:24:23    F9 B5B1062.1  CCAFS SLC-40
# 97   2020-11-16    0:27:00   F9 B5B1061.1     KSC LC-39A
# 98   2020-11-21   17:17:08    F9 B5B1063.1   VAFB SLC-4E
# 99   2020-11-25    2:13:00  F9 B5 B1049.7   CCAFS SLC-40
# 100  2020-12-06   16:17:08  F9 B5 B1058.4     KSC LC-39A
#
#                                                Payload  PAYLOAD_MASS__KG_  \
# 0                 Dragon Spacecraft Qualification Unit                  0
# 1    Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                                Dragon demo flight C2                525
# 3                                         SpaceX CRS-1                500
# 4                                         SpaceX CRS-2                677
# ..                                                 ...                ...
# 96                                 GPS III-04 , Crew-1               4311
# 97                Crew-1, Sentinel-6 Michael Freilich               12500
# 98      Sentinel-6 Michael Freilich, Starlink 15 v1.0                1192
# 99                     Starlink 15 v1.0, SpaceX CRS-21              15600
# 100                                      SpaceX CRS-21               2972
#
#          Orbit                      Customer Mission_Outcome  \
# 0          LEO                        SpaceX         Success
# 1    LEO (ISS)               NASA (COTS) NRO         Success
# 2    LEO (ISS)                   NASA (COTS)         Success
# 3    LEO (ISS)                    NASA (CRS)         Success
# 4    LEO (ISS)                    NASA (CRS)         Success
# ..         ...                           ...             ...
# 96         MEO                          USSF         Success
# 97   LEO (ISS)                    NASA (CCP)         Success
# 98         LEO  NASA / NOAA / ESA / EUMETSAT         Success
# 99         LEO                        SpaceX         Success
# 100  LEO (ISS)                    NASA (CRS)         Success
#
#          Landing_Outcome
# 0    Failure (parachute)
# 1    Failure (parachute)
# 2             No attempt
# 3             No attempt
# 4             No attempt
# ..                   ...
# 96               Success
# 97               Success
# 98               Success
# 99               Success
# 100              Success
#
# [101 rows x 10 columns]

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
# UsageError: Line magic function `%sql` not found.

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
df['Launch_Site'].value_counts()
# Out:
# Launch_Site
# CCAFS SLC-40    34
# CCAFS LC-40     26
# KSC LC-39A      25
# VAFB SLC-4E     16
# Name: count, dtype: int64

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
df[df['Launch_Site'] == 'CCAFS SLC-40']
# Out:
#           Date Time (UTC) Booster_Version   Launch_Site  \
# 44  2017-12-15   15:36:00  F9 FT  B1035.2  CCAFS SLC-40
# 46  2018-01-08    1:00:00   F9 B4 B1043.1  CCAFS SLC-40
# 47  2018-01-31   21:25:00  F9 FT  B1032.2  CCAFS SLC-40
# 49  2018-03-06    5:33:00     F9 B4 B1044  CCAFS SLC-40
# 51  2018-04-02   20:30:00  F9 B4  B1039.2  CCAFS SLC-40
# 52  2018-04-18   22:51:00   F9 B4 B1045.1  CCAFS SLC-40
# 55  2018-06-04    4:45:00  F9 B4  B1040.2  CCAFS SLC-40
# 56  2018-06-29    9:42:00   F9 B4 B1045.2  CCAFS SLC-40
# 57  2018-07-22    5:50:00    F9 B5B1047.1  CCAFS SLC-40
# 59  2018-08-07    5:18:00   F9 B5 B1046.2  CCAFS SLC-40
# 60  2018-09-10    4:45:00    F9 B5B1049.1  CCAFS SLC-40
# 64  2018-12-05   18:16:00      F9 B5B1050  CCAFS SLC-40
# 65  2018-12-23   13:51:00      F9 B5B1054  CCAFS SLC-40
# 67  2019-02-22    1:45:00   F9 B5 B1048.3  CCAFS SLC-40
# 69  2019-05-04    6:48:00   F9 B5B1056.1   CCAFS SLC-40
# 70  2019-05-24    2:30:00   F9 B5 B1049.3  CCAFS SLC-40
# 72  2019-07-25   22:01:00  F9 B5 B1056.2   CCAFS SLC-40
# 73  2019-08-06   23:23:00  F9 B5 B1047.3   CCAFS SLC-40
# 74  2019-11-11   14:56:00   F9 B5 B1048.4  CCAFS SLC-40
# 75  2019-12-05   17:29:00    F9 B5B1059.1  CCAFS SLC-40
# 76  2019-12-17    0:10:00  F9 B5 B1056.3   CCAFS SLC-40
# 77  2020-01-07    2:33:00   F9 B5 B1049.4  CCAFS SLC-40
# 79  2020-01-29   14:07:00   F9 B5 B1051.3  CCAFS SLC-40
# 80  2020-02-17   15:05:00   F9 B5 B1056.4  CCAFS SLC-40
# 81  2020-03-07    4:50:00   F9 B5 B1059.2  CCAFS SLC-40
# 85  2020-06-04    1:25:00   F9 B5 B1049.5  CCAFS SLC-40
# 86  2020-06-13    9:21:00   F9 B5 B1059.3  CCAFS SLC-40
# 87  2020-06-30   20:10:46    F9 B5B1060.1  CCAFS SLC-40
# 88  2020-07-20   21:30:00  F9 B5 B1058.2   CCAFS SLC-40
# 90  2020-08-18   14:31:00   F9 B5 B1049.6  CCAFS SLC-40
# 91  2020-08-30   23:18:00   F9 B5 B1059.4  CCAFS SLC-40
# 95  2020-10-24   15:31:34   F9 B5 B1060.3  CCAFS SLC-40
# 96  2020-11-05   23:24:23    F9 B5B1062.1  CCAFS SLC-40
# 99  2020-11-25    2:13:00  F9 B5 B1049.7   CCAFS SLC-40
#
#                                               Payload  PAYLOAD_MASS__KG_  \
# 44                                      SpaceX CRS-13               2205
# 46                                               Zuma               5000
# 47                                  GovSat-1 / SES-16               4230
# 49                             Hispasat 30W-6  PODSat               6092
# 51                                      SpaceX CRS-14               2647
# 52       Transiting Exoplanet Survey Satellite (TESS)                362
# 55                                             SES-12               5384
# 56                                      SpaceX CRS-15               2697
# 57                                        Telstar 19V               7075
# 59                                       Merah Putih                5800
# 60                            Telstar 18V / Apstar-5C               7060
# 64                                      SpaceX CRS-16               2500
# 65                                        GPS III-01                4400
# 67          Nusantara Satu, Beresheet Moon lander, S5               4850
# 69                       SpaceX CRS-17, Starlink v0.9               2495
# 70              Starlink v0.9, RADARSAT Constellation              13620
# 72                            SpaceX CRS-18, AMOS-17                2268
# 73                          AMOS-17, Starlink 1 v1.0                6500
# 74                    Starlink 1 v1.0, SpaceX CRS-19               15600
# 75               SpaceX CRS-19, JCSat-18 / Kacific 1                2617
# 76             JCSat-18 / Kacific 1, Starlink 2 v1.0                6956
# 77  Starlink 2 v1.0, Crew Dragon in-flight abort t...              15600
# 79                  Starlink 3 v1.0, Starlink 4 v1.0               15600
# 80                     Starlink 4 v1.0, SpaceX CRS-20              15600
# 81                    SpaceX CRS-20, Starlink 5 v1.0                1977
# 85                   Starlink 7 v1.0, Starlink 8 v1.0              15600
# 86  Starlink 8 v1.0, SkySats-16, -17, -18, GPS III...              15410
# 87                              GPS III-03, ANASIS-II               4311
# 88                         ANASIS-II, Starlink 9 v1.0               5500
# 90  Starlink 10 v1.0, SkySat-19, -20, -21, SAOCOM 1B               15440
# 91                    SAOCOM 1B, GNOMES 1, Tyvak-0172               3130
# 95                     Starlink 14 v1.0, GPS III-04                15600
# 96                                GPS III-04 , Crew-1               4311
# 99                    Starlink 15 v1.0, SpaceX CRS-21              15600
#
#         Orbit                                           Customer  \
# 44  LEO (ISS)                                         NASA (CRS)
# 46        LEO                                   Northrop Grumman
# 47        GTO                                                SES
# 49        GTO                                Hispasat  NovaWurks
# 51  LEO (ISS)                                         NASA (CRS)
# 52        HEO                                         NASA (LSP)
# 55        GTO                                                SES
# 56  LEO (ISS)                                         NASA (CRS)
# 57        GTO                                            Telesat
# 59        GTO                                   Telkom Indonesia
# 60        GTO                                            Telesat
# 64  LEO (ISS)                                         NASA (CRS)
# 65        MEO                                               USAF
# 67        GTO                                 PSN, SpaceIL / IAI
# 69  LEO (ISS)                                         NASA (CRS)
# 70        LEO                                             SpaceX
# 72  LEO (ISS)                                         NASA (CRS)
# 73        GTO                                           Spacecom
# 74        LEO                                             SpaceX
# 75  LEO (ISS)                              NASA (CRS), Kacific 1
# 76        GTO                        Sky Perfect JSAT, Kacific 1
# 77        LEO                                             SpaceX
# 79        LEO                                             SpaceX
# 80        LEO                                             SpaceX
# 81  LEO (ISS)                                         NASA (CRS)
# 85        LEO                                SpaceX, Planet Labs
# 86        LEO                                SpaceX, Planet Labs
# 87        MEO                                   U.S. Space Force
# 88        GTO  Republic of Korea Army, Spaceflight Industries...
# 90        LEO                      SpaceX, Planet Labs, PlanetIQ
# 91        SSO                            CONAE, PlanetIQ, SpaceX
# 95        LEO                                             SpaceX
# 96        MEO                                               USSF
# 99        LEO                                             SpaceX
#
#                      Mission_Outcome       Landing_Outcome
# 44                           Success  Success (ground pad)
# 46  Success (payload status unclear)  Success (ground pad)
# 47                           Success    Controlled (ocean)
# 49                           Success            No attempt
# 51                           Success            No attempt
# 52                           Success  Success (drone ship)
# 55                           Success            No attempt
# 56                           Success            No attempt
# 57                           Success               Success
# 59                           Success               Success
# 60                           Success               Success
# 64                           Success               Failure
# 65                          Success             No attempt
# 67                           Success               Success
# 69                           Success               Success
# 70                           Success               Success
# 72                           Success               Success
# 73                           Success           No attempt
# 74                           Success               Success
# 75                           Success               Success
# 76                           Success               Success
# 77                           Success               Success
# 79                           Success               Success
# 80                           Success               Failure
# 81                           Success               Success
# 85                           Success               Success
# 86                           Success               Success
# 87                           Success               Success
# 88                           Success               Success
# 90                           Success               Success
# 91                           Success               Success
# 95                           Success               Success
# 96                           Success               Success
# 99                           Success               Success

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
df[df['Customer'] == 'NASA (CRS)']['PAYLOAD_MASS__KG_'].sum()
# Out:
# 45596

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
df.head()

df[df['Booster_Version'] == 'F9 v1.1']['PAYLOAD_MASS__KG_'].mean()
# Out:
# 2928.4

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
df[df['Landing_Outcome'] == 'Success (ground pad)']
# Out:
#           Date Time (UTC) Booster_Version   Launch_Site  \
# 19  2015-12-22    1:29:00     F9 FT B1019   CCAFS LC-40
# 26  2016-07-18    4:45:00   F9 FT B1025.1   CCAFS LC-40
# 29  2017-02-19   14:39:00   F9 FT B1031.1    KSC LC-39A
# 32  2017-05-01   11:15:00   F9 FT B1032.1    KSC LC-39A
# 34  2017-06-03   21:07:00   F9 FT B1035.1    KSC LC-39A
# 38  2017-08-14   16:31:00   F9 B4 B1039.1    KSC LC-39A
# 40  2017-09-07   14:00:00   F9 B4 B1040.1    KSC LC-39A
# 44  2017-12-15   15:36:00  F9 FT  B1035.2  CCAFS SLC-40
# 46  2018-01-08    1:00:00   F9 B4 B1043.1  CCAFS SLC-40
#
#                                      Payload  PAYLOAD_MASS__KG_      Orbit  \
# 19  OG2 Mission 2  11 Orbcomm-OG2 satellites               2034        LEO
# 26                              SpaceX CRS-9               2257  LEO (ISS)
# 29                             SpaceX CRS-10               2490  LEO (ISS)
# 32                                   NROL-76               5300        LEO
# 34                             SpaceX CRS-11               2708  LEO (ISS)
# 38                             SpaceX CRS-12               3310  LEO (ISS)
# 40                        Boeing X-37B OTV-5               4990        LEO
# 44                             SpaceX CRS-13               2205  LEO (ISS)
# 46                                      Zuma               5000        LEO
#
#             Customer                   Mission_Outcome       Landing_Outcome
# 19           Orbcomm                           Success  Success (ground pad)
# 26        NASA (CRS)                           Success  Success (ground pad)
# 29        NASA (CRS)                           Success  Success (ground pad)
# 32               NRO                           Success  Success (ground pad)
# 34        NASA (CRS)                           Success  Success (ground pad)
# 38        NASA (CRS)                           Success  Success (ground pad)
# 40    U.S. Air Force                           Success  Success (ground pad)
# 44        NASA (CRS)                           Success  Success (ground pad)
# 46  Northrop Grumman  Success (payload status unclear)  Success (ground pad)

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
df[df['Landing_Outcome'] == 'Success (drone ship)']
# Out:
#           Date Time (UTC) Booster_Version   Launch_Site  \
# 22  2016-04-08   20:43:00   F9 FT B1021.1   CCAFS LC-40
# 23  2016-05-06    5:21:00     F9 FT B1022   CCAFS LC-40
# 24  2016-05-27   21:39:00   F9 FT B1023.1   CCAFS LC-40
# 27  2016-08-14    5:26:00     F9 FT B1026   CCAFS LC-40
# 28  2017-01-14   17:54:00   F9 FT B1029.1   VAFB SLC-4E
# 31  2017-03-30   22:27:00  F9 FT  B1021.2    KSC LC-39A
# 35  2017-06-23   19:10:00  F9 FT  B1029.2    KSC LC-39A
# 36  2017-06-25   20:25:00   F9 FT B1036.1   VAFB SLC-4E
# 39  2017-08-24   18:51:00   F9 FT B1038.1   VAFB SLC-4E
# 41  2017-10-09   12:37:00   F9 B4 B1041.1   VAFB SLC-4E
# 42  2017-10-11   22:53:00  F9 FT  B1031.2    KSC LC-39A
# 43  2017-10-30   19:34:00   F9 B4 B1042.1    KSC LC-39A
# 52  2018-04-18   22:51:00   F9 B4 B1045.1  CCAFS SLC-40
# 53  2018-05-11   20:14:00  F9 B5  B1046.1    KSC LC-39A
#
#                                          Payload  PAYLOAD_MASS__KG_  \
# 22                                  SpaceX CRS-8               3136
# 23                                      JCSAT-14               4696
# 24                                     Thaicom 8               3100
# 27                                      JCSAT-16               4600
# 28                                Iridium NEXT 1               9600
# 31                                        SES-10               5300
# 35                                 BulgariaSat-1               3669
# 36                                Iridium NEXT 2               9600
# 39                                    Formosat-5                475
# 41                                Iridium NEXT 3               9600
# 42                         SES-11 / EchoStar 105               5200
# 43                                   Koreasat 5A               3500
# 52  Transiting Exoplanet Survey Satellite (TESS)                362
# 53                                 Bangabandhu-1               3600
#
#         Orbit                Customer Mission_Outcome       Landing_Outcome
# 22  LEO (ISS)              NASA (CRS)         Success  Success (drone ship)
# 23        GTO  SKY Perfect JSAT Group         Success  Success (drone ship)
# 24        GTO                 Thaicom         Success  Success (drone ship)
# 27        GTO  SKY Perfect JSAT Group         Success  Success (drone ship)
# 28  Polar LEO  Iridium Communications         Success  Success (drone ship)
# 31        GTO                     SES         Success  Success (drone ship)
# 35        GTO               Bulsatcom         Success  Success (drone ship)
# 36        LEO  Iridium Communications         Success  Success (drone ship)
# 39        SSO                    NSPO         Success  Success (drone ship)
# 41  Polar LEO  Iridium Communications         Success  Success (drone ship)
# 42        GTO            SES EchoStar         Success  Success (drone ship)
# 43        GTO          KT Corporation         Success  Success (drone ship)
# 52        HEO              NASA (LSP)         Success  Success (drone ship)
# 53        GTO      Thales-Alenia/BTRC         Success  Success (drone ship)

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
df['Mission_Outcome'].value_counts()
# Out:
# Mission_Outcome
# Success                             98
# Failure (in flight)                  1
# Success (payload status unclear)     1
# Success                              1
# Name: count, dtype: int64

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
df[df['PAYLOAD_MASS__KG_'] == df['PAYLOAD_MASS__KG_'].max()]['Booster_Version'].value_counts()
# Out:
# Booster_Version
# F9 B5 B1048.4     1
# F9 B5 B1049.4     1
# F9 B5 B1051.3     1
# F9 B5 B1056.4     1
# F9 B5 B1048.5     1
# F9 B5 B1051.4     1
# F9 B5 B1049.5     1
# F9 B5 B1060.2     1
# F9 B5 B1058.3     1
# F9 B5 B1051.6     1
# F9 B5 B1060.3     1
# F9 B5 B1049.7     1
# Name: count, dtype: int64

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 6,2) as month to get the months and substr(Date,0,5)='2015' for year.**

# %%
df.head(10)
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
# 5  2013-09-29   16:00:00  F9 v1.1  B1003  VAFB SLC-4E
# 6  2013-12-03   22:41:00         F9 v1.1  CCAFS LC-40
# 7  2014-01-06   22:06:00         F9 v1.1  CCAFS LC-40
# 8  2014-04-18   19:25:00         F9 v1.1  CCAFS LC-40
# 9  2014-07-14   15:15:00         F9 v1.1  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
# 5                                           CASSIOPE                500
# 6                                              SES-8               3170
# 7                                          Thaicom 6               3325
# 8                                       SpaceX CRS-3               2296
# 9            OG2 Mission 1  6 Orbcomm-OG2 satellites               1316
#
#        Orbit         Customer Mission_Outcome       Landing_Outcome
# 0        LEO           SpaceX         Success   Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success   Failure (parachute)
# 2  LEO (ISS)      NASA (COTS)         Success            No attempt
# 3  LEO (ISS)       NASA (CRS)         Success            No attempt
# 4  LEO (ISS)       NASA (CRS)         Success            No attempt
# 5  Polar LEO              MDA         Success  Uncontrolled (ocean)
# 6        GTO              SES         Success            No attempt
# 7        GTO          Thaicom         Success            No attempt
# 8  LEO (ISS)       NASA (CRS)         Success    Controlled (ocean)
# 9        LEO          Orbcomm         Success    Controlled (ocean)

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
